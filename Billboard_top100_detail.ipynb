# %%
import billboard
import json
import spotipy
import time
import pandas as pd
import numpy as np
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import datetime
now = datetime.datetime.now().strftime("%Y-%m-%d")
date = now 
#print(date)
username = 'key'
scope =  'key'
client_id = 'key'
client_secret = 'key'
redirect_uri = 'http://localhost:8888'

token = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)
sp = spotipy.Spotify(auth=token)

chart = billboard.ChartData('hot-100', date='%s' % date) 

billboard=[]
for i in chart:
    billboard.append([i.title,i.artist])
#print(billboard)

billboard=pd.DataFrame(billboard)
billboard.columns=['Song_name','Artists']
filename = "billboard_100_song_%s.csv" % date
billboard.to_csv(filename)
print('Billboard 100 song file completed')
#print(billboard)
# Out:
#                      Song_name  \
# 0                     Rockstar
# 1                       Havana
# 2   Bodak Yellow (Money Moves)
# 3         Too Good At Goodbyes
# 4                      Thunder
# 5               1-800-273-8255
# 6                Feel It Still
# 7                      Perfect
# 8               What Lovers Do
# 9                     Mi Gente
# 10             Sorry Not Sorry
# 11                  Gucci Gang
# 12                    No Limit
# 13               I Get The Bag
# 14                Bank Account
# 15               Unforgettable
# 16               What About Us
# 17                   Despacito
# 18                   Attention
# 19                 Bad At Love
# 20                   New Rules
# 21                  Rake It Up
# 22                  MotorSport
# 23                    Believer
# 24          Young Dumb & Broke
# 25                Shape Of You
# 26       Call It What You Want
# 27                     Praying
# 28                I Fall Apart
# 29            ...Ready For It?
# ..                         ...
# 70                 Fix A Drink
# 71               Good Old Days
# 72       My Choppa Hate N****s
# 73                       Yours
# 74     I Could Use A Love Song
# 75             Round Here Buzz
# 76              Jocelyn Flores
# 77                   Questions
# 78        Rubbin Off The Paint
# 79              Dusk Till Dawn
# 80                 Candy Paint
# 81                        Pray
# 82                   F**k Love
# 83             Lights Down Low
# 84                    Gorgeous
# 85                Transportin'
# 86                Relationship
# 87                     Mayores
# 88                 Sauce It Up
# 89           Ask Me How I Know
# 90                      Smooth
# 91                Broken Halos
# 92                        Wait
# 93             Pull Up N Wreck
# 94        You Broke Up With Me
# 95                     Go Flex
# 96                 Patek Water
# 97                    Glorious
# 98                Mad Stalkers
# 99                   Nightmare
#
#                                               Artists
# 0                     Post Malone Featuring 21 Savage
# 1                 Camila Cabello Featuring Young Thug
# 2                                             Cardi B
# 3                                           Sam Smith
# 4                                     Imagine Dragons
# 5               Logic Featuring Alessia Cara & Khalid
# 6                                   Portugal. The Man
# 7                                          Ed Sheeran
# 8                              Maroon 5 Featuring SZA
# 9          J Balvin & Willy William Featuring Beyonce
# 10                                        Demi Lovato
# 11                                           Lil Pump
# 12              G-Eazy Featuring A$AP Rocky & Cardi B
# 13                         Gucci Mane Featuring Migos
# 14                                          21 Savage
# 15                  French Montana Featuring Swae Lee
# 16                                               P!nk
# 17  Luis Fonsi & Daddy Yankee Featuring Justin Bieber
# 18                                       Charlie Puth
# 19                                             Halsey
# 20                                           Dua Lipa
# 21                     Yo Gotti Featuring Nicki Minaj
# 22                       Migos, Nicki Minaj & Cardi B
# 23                                    Imagine Dragons
# 24                                             Khalid
# 25                                         Ed Sheeran
# 26                                       Taylor Swift
# 27                                              Kesha
# 28                                        Post Malone
# 29                                       Taylor Swift
# ..                                                ...
# 70                                       Chris Janson
# 71                         Macklemore Featuring Kesha
# 72                           21 Savage & Metro Boomin
# 73                                  Russell Dickerson
# 74                                       Maren Morris
# 75                                        Eric Church
# 76                                       XXXTentacion
# 77                                        Chris Brown
# 78                                         YBN Nahmir
# 79                                 Zayn Featuring Sia
# 80                                        Post Malone
# 81                                          Sam Smith
# 82                XXXTentacion Featuring Trippie Redd
# 83                                MAX Featuring gnash
# 84                                       Taylor Swift
# 85                                        Kodak Black
# 86                        Young Thug Featuring Future
# 87                        Becky G Featuring Bad Bunny
# 88                                       Lil Uzi Vert
# 89                                       Garth Brooks
# 90                               Florida Georgia Line
# 91                                    Chris Stapleton
# 92                                           Maroon 5
# 93        Big Sean & Metro Boomin Featuring 21 Savage
# 94                                       Walker Hayes
# 95                                        Post Malone
# 96               Future & Young Thug Featuring Offset
# 97                   Macklemore Featuring Skylar Grey
# 98                   21 Savage, Offset & Metro Boomin
# 99                              Offset & Metro Boomin
#
# [100 rows x 2 columns]

# %%
#artist = sp.search(q='Khalid',type = 'artist')
#for i in artist['artists']['items'][0]:
 #   print(i)
#print(artist['artists']['items'][0]['id'])
artists=[]
for i in billboard['Artists']:
    token = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)
    sp = spotipy.Spotify(auth=token)
    results = sp.search(q=i,type = 'artist')
    if len(results['artists']['items']) >0:
           artists.append((results['artists']['items'][0]['id']))
            
#print(artists)
# Out:
# ['4kYSro6naA4h99UJvo89HB', '2wY79sveU1sp5g7SokKOiI', '53XhwfbYqKCa1cC15pYq2q', '4kI8Ie27vjvonwaB2ePh8T', '6eUKZXaKkcviH0Ku9w2n3V', '6S2OmqARrzebs0tKUEyXyp', '3wyVrVrFCkukjdVIdirGVY', '1URnnhqYAYcrqrcwql10ft', '1KCSPY1glIKqW2TotWuXOR', '6VuMaDnrHyPL1p4EHjYLi7', '26VFTg2z8YR0cCuwLzESi2', '6M2wZ9GZgrQXHCFfjv46we', '53XhwfbYqKCa1cC15pYq2q', '6LuN9FCkKOj5PcnpouEgny', '6eUKZXaKkcviH0Ku9w2n3V', '06HL4z0CvFAxyc27GXpf02', '6LqNN22kT3074XbTVUrhzX', '246dkjvS1zLTtiykXe5h60', '06HL4z0CvFAxyc27GXpf02', '7n2wHs1TKAczGzO7Dd2rGr', '1Hsdzj7Dlq2I7tHP7501T4', '0du5cEVh5yTK9QJze8zA0C', '06HL4z0CvFAxyc27GXpf02', '718COspgdWOnwOFpJHRZHS', '2cFrymmkijnjDg9SS92EPM', '7tYKF4w9nC0nq9CsPZTHyP', '6VuMaDnrHyPL1p4EHjYLi7', '4O15NlyKLIASxsJ0PrXPfz', '2YZyLoL8N0Wb9xBt1NhZWg', '2kucQ9jQwuD8jWdtR9Ef38', '2lRH2dgU5Kk4Bc5phmII4T', '6x2LnllRG5uGarZMsD4iO8', '3BmGtnKgCSGYIUhmivXKWX', '1UTPBmNbXNTittyMJrNkvw', '5dHt1vcEm9qb8fCyLcB3HL', '4sIl4BTo9l9KqEi0Y3RE72', '6fOMl44jA4Sp5b9PpYCkzz', '0BvkDsjIUla7X0k6CSWh1I', '2ODbg2404zUzTi02qIPEjB', '0fiWOxhsBsQQvFDtxUQWo0', '4BYxqVkZyFjtik7crYLg5Q', '60gmlHZmT16wiO9GiXKYK9', '1E2AEtxaFaJtH0lO7kgNKw', '6WY7D3jk8zTrHtmkqqo5GI', '2IvkS5MXK0vPGnwyJsrEyV', '15UsOTVnJzReFVN1VCnxy4', '7bXgB6jMjp9ATFy66eO08Z', '3gGUMEwIX6XodWsYEvKSal', '246dkjvS1zLTtiykXe5h60', '2wY79sveU1sp5g7SokKOiI', '06HL4z0CvFAxyc27GXpf02', '46SHBwWsqBkxI7EeeBEQG7', '4O15NlyKLIASxsJ0PrXPfz', '4BclNkZtAUq1YrYNzye3N7', '3b8QkneNDz4JHKKKlLgYZg', '4YLtscXsxbVgi031ovDDdh', '04gDigrS5kc9YWfZHwBETP', '7sKxqpSqbIzphAKAhrqvlf', '246dkjvS1zLTtiykXe5h60']

# %%
##### get artists details  ######
artist_details = []
for i in artists:
    token = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)
    spotify = spotipy.Spotify(auth=token)

    artist = spotify.artist(i)
    related = sp.artist_related_artists(i)
    related_artist = []
    for j in range(len(related['artists'])):
        related_artist.append([related['artists'][j]['name']])
    name = artist['name']
    artist_id = i
    follower = artist['followers']
    follower2 = follower['total']
    genre = artist['genres']
    spotify_id = artist['id']
    image = artist['images']
    popularity = artist['popularity']
    artist_details.append([artist_id,name,follower2,genre,spotify_id,image,popularity,related_artist])

artist_details2 = pd.DataFrame(artist_details)
artist_details2.columns = ['artist_id','name','follower','genre','spotify_id','image','popularity','related_artist']

filename = "billboard_100_artists_detail_%s.csv" % date
artist_details2.to_csv(filename)
print('artist detail file completed')
# Out:
# artist detail file completed

# %%
##### get artists album details #####

token = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)
spotify = spotipy.Spotify(auth=token)

album_list=[]
for i in artists:
    albums = []
    token = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)
    spotify = spotipy.Spotify(auth=token)
    results = sp.artist_albums(i, album_type='album')
    albums.extend(results['items'])
    while results['next']:
        results = sp.next(results)
        albums.extend(results['items'])
    seen = set() # to avoid dups
    albums.sort(key=lambda album:album['name'].lower())
    for album in albums:
        name = album['name']
        album_id = album['id']
        if name not in seen:
            album_list.append([ name, album_id,i])
            seen.add(name)

album_list2=pd.DataFrame(album_list)
album_list2.columns=['album_name','album_id','artist_id']

token = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)
sp = spotipy.Spotify(auth=token)


album_details=[]
for i in album_list2['album_id']:
    
    #album_id = i
    #album_id = re.search('album\:(.+)', album_id).group(1)
    token = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)
    spotify = spotipy.Spotify(auth=token)
    detail1 = sp.album(i)
    artist_id = detail1['artists'][0]['id']
    album_name = detail1['name']
    market = detail1['available_markets']
    #print(artist_id)
    #artist_name = sp.artist(artist_id)
    #artist_name2 = artist_name['name']
    genres = detail1['genres']
    popularity = detail1['popularity']
    release_date = detail1['release_date']
    image = detail1['images']
    tracks = detail1['tracks']
    album_details.append([artist_id,
                          album_name,
                          i,market,genres,popularity,release_date,image,tracks])

album_details=pd.DataFrame(album_details)
album_details.columns=['Artist_id','Album_name','Album_id','available_markets','genres','popularity',
                   'release_date','image','tracks']

filename = "billboard_100_artists_album_details_%s.csv" % date
album_details.to_csv(filename)
print('artists album detais file completed')
# Out:
# artists album detais file completed

# %%
###### get artists top song detail #####
import re

token = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)
sp = spotipy.Spotify(auth=token)


tids = []
for i in artists:
    token = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)
    sp = spotipy.Spotify(auth=token)
    results = sp.artist_top_tracks(i)
    
    #print(results)
    for j in (results['tracks']):
        #print(i['name'])
        tids.append([j['name'],j['id'],i])
#print(tids)
tids = pd.DataFrame(tids)
tids.columns=['song_name','song_id','artist_id']

details = []
#available_market=[]

username = 'key'
scope =  'key'
client_id = 'key'
client_secret = 'key'
redirect_uri = 'http://localhost:8888'

for song in tids['song_id']:
    track = sp.track(song)
    token = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)
    sp = spotipy.Spotify(auth=token)
    features = sp.audio_features(song)
    #features[0]['danceability'] = 0 if features is None
    for i in track['artists']:
    #for j in i['Artist']:
        #print(song)
        danceability=0 if features == [None] else features[0]['danceability']
        energy=0 if features == [None] else features[0]['energy']
        key = 0 if features ==[None] else features[0]['key']
        loudness= 0 if features == [None] else features[0]['loudness']
        mode = 0 if features == [None] else features[0]['mode']              
        speechiness= 0 if features == [None] else features[0]['speechiness']
        acousticness= 0 if features == [None] else features[0]['acousticness']
        instrumentalness = 0 if  features == [None] else features[0]['instrumentalness']
        liveness = 0 if  features == [None] else features[0]['liveness']
        valence = 0 if  features == [None] else features[0]['valence']
        tempo = 0 if features == [None] else features[0]['tempo']
        type2 = 0 if features == [None] else features[0]['type']
        duration_ms = 0 if  features == [None] else features[0]['duration_ms']
        details.append([song,i['name'],i['id'],[re.search('album\:(.+)', track['album']['uri']).group(1)],
                        danceability,
                        energy,
                        key,
                        loudness,
                        mode,
                        speechiness,
                        acousticness,
                        instrumentalness,
                        liveness,
                        valence,
                        tempo,
                        type2,
                        duration_ms, 
                        track['available_markets'],track['disc_number'],track['track_number']])
        #danceability.append(features[0]['danceability'])
        #for j in track['available_markets']:
            #details.append([j])
            #for k in track['popularity']:
             #   details.append(k)

#for i in track['available_markets']:
 #   available_market.append(i)
    
#print(type(track))    
datails = pd.DataFrame(details)
details2=pd.DataFrame(details)
details2.columns=['song_id','Artist_name','Artist_id','album_id','danceability','energy','key','loudness','mode','speechiness',
                 'acousticness','instrumentalness','liveness','valence','tempo','type','duration_ms','available_markets',
                 'Disc_Number','track_number']
#print(details2)
#print(available_market)

#details2.to_csv('songs.csv')
filename = "billboard_100_artists_top_song_detail_%s.csv" % date
details2.to_csv(filename)
print('artists top songs detail file completed')
# Out:
# artists top songs detail file completed

# %%
##### billboard 100 song detail ####

token = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)
sp = spotipy.Spotify(auth=token)
#song_id = []

details = []
song_list = []
for i in billboard['Song_name']:
    track=(sp.search(q=i,type = 'track'))
    song_id = track['tracks']['items'][0]['id']
    song_name = track['tracks']['items'][0]['name']
    song_list.append([song_id,song_name])
    
song_list=pd.DataFrame(song_list)
song_list.columns=['song_id','song_name']

for inx, song in enumerate(song_list['song_id']):
    track = sp.track(song)
    features = sp.audio_features(song)
    song_name = song_list['song_name'].loc[inx]
    for i in track['artists']:
        token = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)
        sp = spotipy.Spotify(auth=token)
        danceability=0 if features == [None] else features[0]['danceability']
        energy=0 if features == [None] else features[0]['energy']
        key = 0 if features ==[None] else features[0]['key']
        loudness= 0 if features == [None] else features[0]['loudness']
        mode = 0 if features == [None] else features[0]['mode']              
        speechiness= 0 if features == [None] else features[0]['speechiness']
        acousticness= 0 if features == [None] else features[0]['acousticness']
        instrumentalness = 0 if  features == [None] else features[0]['instrumentalness']
        liveness = 0 if  features == [None] else features[0]['liveness']
        valence = 0 if  features == [None] else features[0]['valence']
        tempo = 0 if features == [None] else features[0]['tempo']
        type2 = 0 if features == [None] else features[0]['type']
        duration_ms = 0 if  features == [None] else features[0]['duration_ms']
        details.append([song,song_name,i['name'],i['id'],[re.search('album\:(.+)', track['album']['uri']).group(1)],
                        danceability,
                        energy,
                        key,
                        loudness,
                        mode,
                        speechiness,
                        acousticness,
                        instrumentalness,
                        liveness,
                        valence,
                        tempo,
                        type2,
                        duration_ms,
                        track['available_markets'],track['disc_number'],track['track_number']])

        #for j in track['available_markets']:
         #   details.append([j])
            #for k in track['popularity']:
             #   details.append(k)

#for i in track['available_markets']:
 #   available_market.append(i)
    
#print(type(track))    
datails = pd.DataFrame(details)
details3=pd.DataFrame(details)
details3.columns=['song_id','Song_name','Artist_name','Artist_id','album_id','danceability','energy','key','loudness','mode','speechiness',
                 'acousticness','instrumentalness','liveness','valence','tempo','type','duration_ms','available_markets',
                 'Disc_Number','track_number']

        #for j in track['available_markets']:
         #   details.append([j])
            #for k in track['popularity']:
             #   details.append(k)

#for i in track['available_markets']:
 #   available_market.append(i)
    
#print(type(track))    

filename = "billboard_100_song_detail_%s.csv" % date
details3.to_csv(filename)

print('billboard 100 song detail file completed')
# Out:
# billboard 100 song detail file completed
